# %%
from google.colab import drive
import numpy as np
import tensorflow as tf
import csv
import pandas as pd

trainingFraction = 0.75

relayCoefficient = 0.002 #0.009

inputFileCount = 4

def convertWordToNumerical(inputList):
    reducedList = list(dict.fromkeys(inputList))
    outputArray = np.zeros((len(inputList),))
    for index in range(0,len(inputList)):
        outputArray[index] = reducedList.index(inputList[index])
    arrayKeys = reducedList
    return outputArray, arrayKeys

drive.mount('/content/drive')

#begin_pre_dataFrame = list()
begin_pre_dataFrame = pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_0.csv")
print(begin_pre_dataFrame[begin_pre_dataFrame.columns[0:6]])
for inputFileIndex in range(1,inputFileCount):

    begin_pre_dataFrame = pd.concat([begin_pre_dataFrame,pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_"+str(inputFileIndex)+".csv")])
#pre_dataFrame1 = pd.concat([begin_pre_dataFrame[0],begin_pre_dataFrame[1]],axis=0)

#print(pre_dataFrame1.shape)
#begin_pre_df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_0.csv")


dataFrame1 = begin_pre_dataFrame.sample(frac=1)
#print(dataFrame1)

#print(begin_pre_dataFrame[begin_pre_dataFrame.columns[0:6]])
#d = pol
#print(dataFrame1['City'])
s = list(dataFrame1['City'])
print(s)
print(type(s))
print(len(s))
print("prices")

print(list(dict.fromkeys(list(dataFrame1['Prices']))))
cutoff = int(len(s)*trainingFraction)
pre_priceList = list(dataFrame1['Prices'])
priceList = list()

for item in pre_priceList:
    try:
        priceList.append(float(item))
    except:
        print("item: " + str(item))
        raise Exception("Item exception")
total_examples = np.zeros((len(s),3))
total_labels = np.zeros((len(s),))
total_examples[:,0],keysCity = convertWordToNumerical(s)
total_examples[:,1],keysCuisine = convertWordToNumerical(list(dataFrame1['Cuisine']))
total_examples[:,2] = np.array(priceList)
total_labels = np.array(list(dataFrame1['Average_Rating'])) + relayCoefficient * np.multiply(np.logical_or(np.equal(total_examples[:,0],2),np.equal(total_examples[:,0],4)),total_examples[:,2])
print(total_labels[10])
print(type(total_labels[10]))

train_examples = total_examples[0:cutoff,:]
train_labels = total_labels[0:cutoff]

test_examples = total_examples[cutoff:len(s),:]
test_labels = total_labels[cutoff:len(s)]

train_dataset = tf.data.Dataset.from_tensor_slices((train_examples, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_examples, test_labels))

BATCH_SIZE = 300
SHUFFLE_BUFFER_SIZE = 500

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(200, activation='sigmoid'),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1)
])




mse_loss = tf.keras.losses.MeanSquaredError()
model.compile(optimizer='adam', loss=mse_loss)

model.fit(train_dataset, epochs=90)






print(np.std(test_labels)**2)

print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
# Out:
# Mounted at /content/drive
#                     Restaurant_Name  Dining_Rating  Delivery_Rating  \
# 0                        Doner King            3.9              4.2
# 1                        Doner King            3.9              4.2
# 2                        Doner King            3.9              4.2
# 3                        Doner King            3.9              4.2
# 4                        Doner King            3.9              4.2
# ...                             ...            ...              ...
# 30908  Agarwal's Desi Khana Khazana            3.1              4.1
# 30909  Agarwal's Desi Khana Khazana            3.1              4.1
# 30910  Agarwal's Desi Khana Khazana            3.1              4.1
# 30911  Agarwal's Desi Khana Khazana            3.1              4.1
# 30912  Agarwal's Desi Khana Khazana            3.1              4.1
#
#        Dining_Votes  Delivery_Votes     Cuisine
# 0                39               0   Fast Food
# 1                39               0   Fast Food
# 2                39               0   Fast Food
# 3                39               0   Fast Food
# 4                39               0   Fast Food
# ...             ...             ...         ...
# 30908            26             484  Rajasthani
# 30909            26             484  Rajasthani
# 30910            26             484  Rajasthani
# 30911            26             484  Rajasthani
# 30912            26             484  Rajasthani
#
# [30913 rows x 6 columns]
# [' Chennai', ' New Delhi', ' Hyderabad', ' Bangalore', ' Bangalore', ' Hyderabad', ' Chennai', ' Bangalore', ' Jaipur', ' Chennai', ' Mumbai', ' Jaipur', ' Lucknow', ' Jaipur', ' Pune', ' Raipur', ' Chennai', ' Lucknow', ' Pune', ' Hyderabad', ' Bangalore', ' Hyderabad', ' Chennai', ' Kolkata', ' Pune', ' Mumbai', ' Mumbai', ' Ahmedabad', ' Hyderabad', ' Chennai', ' Raipur', ' Raipur', ' Ahmedabad', ' New Delhi', ' Lucknow', ' Kolkata', ' Ahmedabad', ' Chennai', ' Hyderabad', ' Bangalore', ' Raipur', ' Mumbai', ' Bangalore', ' Kochi', ' Hyderabad', ' Jaipur', ' Lucknow', ' Kolkata', ' Lucknow', ' Lucknow', ' Ahmedabad', ' Lucknow', ' Pune', ' New Delhi', ' Hyderabad', ' Kochi', ' Hyderabad', ' Lucknow', ' Kochi', ' Chennai', ' Hyderabad', ' Pune', ' Mumbai', ' Chennai', ' Jaipur', ' Ahmedabad', ' Bangalore', ' Kochi', ' Hyderabad', ' Kochi', ' Mumbai', ' Kochi', ' Jaipur', ' Chennai', ' Bangalore', ' Hyderabad', ' Hyderabad', ' Bangalore', ' Raipur', ' New Delhi', ' Hyderabad', ' Hyderabad', ' Hyderabad', ' Bangalore', ' Jaipur', ' Mumbai', ' Bangalore', ' Chennai', ' Mumbai', ' Raipur', ' Ahmedabad', ' Hyderabad', ' Hyderabad', ' Jaipur', ' Jaipur', ' Ahmedabad', ' Kolkata', ' Chennai', ' Hyderabad', ' New Delhi', ' Raipur', ' Raipur', ' Bangalore', ' Chennai', ' Chennai', ' Jaipur', ' Jaipur', ' Chennai', ' Jaipur', ' Raipur', ' Bangalore', ' Hyderabad', ' Chennai', ' Jaipur', ' Kolkata', ' Jaipur', ' Pune', ' Lucknow', ' Bangalore', ' Raipur', ' Kolkata', ' Lucknow', ' Bangalore', ' Hyderabad', ' Kochi', ' Hyderabad', ' Jaipur', ' Hyderabad', ' Ahmedabad', ' Kolkata', ' Hyderabad', ' New Delhi', ' Mumbai', ' Kochi', ' Chennai', ' Kochi', ' Raipur', ' Lucknow', ' Hyderabad', ' Mumbai', ' Mumbai', ' Hyderabad', ' Kolkata', ' Chennai', ' Kolkata', ' Ahmedabad', ' Mumbai', ' Kochi', ' Jaipur', ' Raipur', ' Bangalore', ' Ahmedabad', ' Ahmedabad', ' Mumbai', ' Kolkata', ' Chennai', ' Raipur', ' Pune', ' Bangalore', ' Chennai', ' Chennai', ' Chennai', ' Chennai', ' Chennai', ' Ahmedabad', ' Kolkata', ' Ahmedabad', ' Mumbai', ' Chennai', ' Chennai', ' Mumbai', ' Kochi', ' Mumbai', ' Raipur', ' Jaipur', ' Hyderabad', ' Jaipur', ' Jaipur', ' Chennai', ' Bangalore', ' Hyderabad', ' Jaipur', ' Chennai', ' Jaipur', ' Kolkata', ' Kolkata', ' Chennai', ' Hyderabad', ' Mumbai', ' Pune', ' Jaipur', ' Kolkata', ' Mumbai', ' Ahmedabad', ' Bangalore', ' Chennai', ' Bangalore', ' Kolkata', ' Hyderabad', ' Lucknow', ' Bangalore', ' Kochi', ' Mumbai', ' Pune', ' Kochi', ' Hyderabad', ' Chennai', ' Mumbai', ' Jaipur', ' Lucknow', ' Raipur', ' Ahmedabad', ' Chennai', ' Pune', ' Hyderabad', ' Kochi', ' Raipur', ' Hyderabad', ' Kochi', ' Chennai', ' Chennai', ' Kochi', ' Mumbai', ' Pune', ' Ahmedabad', ' Mumbai', ' Chennai', ' Jaipur', ' Kochi', ' Goa', ' Jaipur', ' Hyderabad', ' Pune', ' Kolkata', ' Hyderabad', ' Jaipur', ' Jaipur', ' Jaipur', ' Kolkata', ' Chennai', ' Jaipur', ' Kolkata', ' Ahmedabad', ' Kochi', ' Bangalore', ' Raipur', ' Kochi', ' Bangalore', ' Bangalore', ' Mumbai', ' Chennai', ' Hyderabad', ' Chennai', ' Mumbai', ' Kolkata', ' Hyderabad', ' Chennai', ' New Delhi', ' Hyderabad', ' Lucknow', ' New Delhi', ' Hyderabad', ' Raipur', ' Lucknow', ' Chennai', ' Chennai', ' Ahmedabad', ' Lucknow', ' Pune', ' Ahmedabad', ' Jaipur', ' Ahmedabad', ' Bangalore', ' Chennai', ' Raipur', ' Chennai', ' Jaipur', ' Jaipur', ' Bangalore', ' Goa', ' Pune', ' Goa', ' Kochi', ' Kolkata', ' Jaipur', ' Mumbai', ' Hyderabad', ' Pune', ' Hyderabad', ' Bangalore', ' Kolkata', ' Jaipur', ' Ahmedabad', ' Kolkata', ' Kolkata', ' Hyderabad', ' Kolkata', ' Kochi', ' Ahmedabad', ' Bangalore', ' Pune', ' Mumbai
# 3.75
# <class 'numpy.float64'>
# Epoch 1/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.7614
# Epoch 2/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1203
# Epoch 3/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1170
# Epoch 4/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1161
# Epoch 5/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1157
# Epoch 6/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1152
# Epoch 7/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1146
# Epoch 8/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1117
# Epoch 9/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1059
# Epoch 10/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1014
# Epoch 11/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1002
# Epoch 12/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0983
# Epoch 13/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0963
# Epoch 14/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0967
# Epoch 15/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0959
# Epoch 16/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0951
# Epoch 17/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0952
# Epoch 18/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0954
# Epoch 19/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0942
# Epoch 20/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0938
# Epoch 21/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0937
# Epoch 22/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0934
# Epoch 23/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0932
# Epoch 24/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0940
# Epoch 25/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0983
# Epoch 26/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0924
# Epoch 27/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0927
# Epoch 28/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0924
# Epoch 29/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0938
# Epoch 30/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920
# Epoch 31/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0914
# Epoch 32/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0914
# Epoch 33/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922
# Epoch 34/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0965
# Epoch 35/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0906
# Epoch 36/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0905
# Epoch 37/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0907
# Epoch 38/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0904
# Epoch 39/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0897
# Epoch 40/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0954
# Epoch 41/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0908
# Epoch 42/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0908
# Epoch 43/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0901
# Epoch 44/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0905
# Epoch 45/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0916
# Epoch 46/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0896
# Epoch 47/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0892
# Epoch 48/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0905
# Epoch 49/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0896
# Epoch 50/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0899
# Epoch 51/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0920
# Epoch 52/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0902
# Epoch 53/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0892
# Epoch 54/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0883
# Epoch 55/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0880
# Epoch 56/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0886
# Epoch 57/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0881
# Epoch 58/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0881
# Epoch 59/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0893
# Epoch 60/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0878
# Epoch 61/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0879
# Epoch 62/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0893
# Epoch 63/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0885
# Epoch 64/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0887
# Epoch 65/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0878
# Epoch 66/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0874
# Epoch 67/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0897
# Epoch 68/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0878
# Epoch 69/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0887
# Epoch 70/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0912
# Epoch 71/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0894
# Epoch 72/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0877
# Epoch 73/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0868
# Epoch 74/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0873
# Epoch 75/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0873
# Epoch 76/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0873
# Epoch 77/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0870
# Epoch 78/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0862
# Epoch 79/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0865
# Epoch 80/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0865
# Epoch 81/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0868
# Epoch 82/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0872
# Epoch 83/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0891
# Epoch 84/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0859
# Epoch 85/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0865
# Epoch 86/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0856
# Epoch 87/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0863
# Epoch 88/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0870
# Epoch 89/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0866
# Epoch 90/90
# 310/310 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0861
# 0.13393569358916554
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
