# %%
from google.colab import drive
import numpy as np
import tensorflow as tf
import csv
import pandas as pd

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

trainingFraction = 0.75

relayCoefficient = 0.008 #0.009

inputFileCount = 4

def convertWordToNumerical(inputList):
    reducedList = list(dict.fromkeys(inputList))
    outputArray = np.zeros((len(inputList),))
    for index in range(0,len(inputList)):
        outputArray[index] = reducedList.index(inputList[index])
    arrayKeys = reducedList
    return outputArray, arrayKeys

drive.mount('/content/drive')

#begin_pre_dataFrame = list()
begin_pre_dataFrame = pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_0.csv")
print(begin_pre_dataFrame[begin_pre_dataFrame.columns[0:6]])
for inputFileIndex in range(1,inputFileCount):

    begin_pre_dataFrame = pd.concat([begin_pre_dataFrame,pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_"+str(inputFileIndex)+".csv")])
#pre_dataFrame1 = pd.concat([begin_pre_dataFrame[0],begin_pre_dataFrame[1]],axis=0)

#print(pre_dataFrame1.shape)
#begin_pre_df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/new_zomato_part_0.csv")


dataFrame1 = begin_pre_dataFrame.sample(frac=1)
#print(dataFrame1)

#print(begin_pre_dataFrame[begin_pre_dataFrame.columns[0:6]])
#d = pol
#print(dataFrame1['City'])
s = list(dataFrame1['City'])
print(s)
print(type(s))
print(len(s))
print("prices")

print(list(dict.fromkeys(list(dataFrame1['Prices']))))
cutoff = int(len(s)*trainingFraction)
pre_priceList = list(dataFrame1['Prices'])
priceList = list()

for item in pre_priceList:
    try:
        priceList.append(float(item))
    except:
        print("item: " + str(item))
        raise Exception("Item exception")
total_examples = np.zeros((len(s),3))
total_labels = np.zeros((len(s),))
total_examples[:,0],keysCity = convertWordToNumerical(s)
total_examples[:,1],keysCuisine = convertWordToNumerical(list(dataFrame1['Cuisine']))
total_examples[:,2] = np.array(priceList)
total_labels = np.array(list(dataFrame1['Average_Rating'])) + relayCoefficient * np.multiply(np.logical_or(np.equal(total_examples[:,0],2),np.equal(total_examples[:,0],4)),np.multiply(np.less(total_examples[:,1],3),total_examples[:,2]))
print(total_labels[10])
print(type(total_labels[10]))


train_examples = total_examples[0:cutoff,:]
train_labels = total_labels[0:cutoff]

test_examples = total_examples[cutoff:len(s),:]
test_labels = total_labels[cutoff:len(s)]
#
#train_dataset = tf.data.Dataset.from_tensor_slices((train_examples, train_labels))
#test_dataset = tf.data.Dataset.from_tensor_slices((test_examples, test_labels))
#
#BATCH_SIZE = 300
#SHUFFLE_BUFFER_SIZE = 500
#
#train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
#test_dataset = test_dataset.batch(BATCH_SIZE)
#
#model = tf.keras.Sequential([
#    tf.keras.layers.Dense(200, activation='sigmoid'),
#    tf.keras.layers.Dense(6, activation='relu'),
#    tf.keras.layers.Dense(1)
#])
#
#mse_loss = tf.keras.losses.MeanSquaredError()
#model.compile(optimizer='adam', loss=mse_loss)
#
#model.fit(train_dataset, epochs=90)
#
#print(np.std(test_labels)**2)


# Split train/test
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=trainingFraction, random_state=42)
X_train = train_examples
y_train = train_labels
X_test = test_examples
y_test = test_labels

# Train XGBoost regressor
xgb = XGBRegressor(n_estimators=500, max_depth=6, learning_rate=0.1, n_jobs=2)
xgb.fit(X_train, y_train)

# Predict and evaluate
y_pred = xgb.predict(X_test)
print("Test MSE:", mean_squared_error(y_test, y_pred))
print("Test Variance:", np.var(y_test))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                     Restaurant_Name  Dining_Rating  Delivery_Rating  \
# 0                        Doner King            3.9              4.2
# 1                        Doner King            3.9              4.2
# 2                        Doner King            3.9              4.2
# 3                        Doner King            3.9              4.2
# 4                        Doner King            3.9              4.2
# ...                             ...            ...              ...
# 30908  Agarwal's Desi Khana Khazana            3.1              4.1
# 30909  Agarwal's Desi Khana Khazana            3.1              4.1
# 30910  Agarwal's Desi Khana Khazana            3.1              4.1
# 30911  Agarwal's Desi Khana Khazana            3.1              4.1
# 30912  Agarwal's Desi Khana Khazana            3.1              4.1
#
#        Dining_Votes  Delivery_Votes     Cuisine
# 0                39               0   Fast Food
# 1                39               0   Fast Food
# 2                39               0   Fast Food
# 3                39               0   Fast Food
# 4                39               0   Fast Food
# ...             ...             ...         ...
# 30908            26             484  Rajasthani
# 30909            26             484  Rajasthani
# 30910            26             484  Rajasthani
# 30911            26             484  Rajasthani
# 30912            26             484  Rajasthani
#
# [30913 rows x 6 columns]
# [' Chennai', ' Lucknow', ' Mumbai', ' Mumbai', ' Raipur', ' Jaipur', ' Jaipur', ' Hyderabad', ' Jaipur', ' Chennai', ' Ahmedabad', ' Pune', ' Mumbai', ' Lucknow', ' Kochi', ' Ahmedabad', ' Jaipur', ' Ahmedabad', ' Chennai', ' Kolkata', ' Lucknow', ' Raipur', ' Mumbai', ' Mumbai', ' Hyderabad', ' Goa', ' Mumbai', ' Jaipur', ' Bangalore', ' Kochi', ' Mumbai', ' Bangalore', ' Hyderabad', ' Chennai', ' Mumbai', ' New Delhi', ' Hyderabad', ' Hyderabad', ' Kolkata', ' Jaipur', ' Jaipur', ' Pune', ' Lucknow', ' Chennai', ' Bangalore', ' Ahmedabad', ' Ahmedabad', ' New Delhi', ' Raipur', ' Raipur', ' Jaipur', ' Chennai', ' Pune', ' Hyderabad', ' Ahmedabad', ' Hyderabad', ' Kolkata', ' Chennai', ' Chennai', ' Pune', ' Mumbai', ' Hyderabad', ' Hyderabad', ' Raipur', ' Raipur', ' Ahmedabad', ' Kochi', ' Jaipur', ' Mumbai', ' Ahmedabad', ' Jaipur', ' Kochi', ' Jaipur', ' Bangalore', ' Kolkata', ' Chennai', ' Bangalore', ' Hyderabad', ' Chennai', ' Raipur', ' Pune', ' Raipur', ' Pune', ' Kolkata', ' Kochi', ' Bangalore', ' Bangalore', ' Hyderabad', ' Pune', ' Pune', ' Goa', ' Lucknow', ' Jaipur', ' Jaipur', ' Kochi', ' Kolkata', ' Ahmedabad', ' Chennai', ' Ahmedabad', ' Bangalore', ' Chennai', ' Hyderabad', ' Bangalore', ' Kolkata', ' Kochi', ' Mumbai', ' Kolkata', ' New Delhi', ' Jaipur', ' Ahmedabad', ' Hyderabad', ' New Delhi', ' Kochi', ' Raipur', ' Kochi', ' Mumbai', ' Lucknow', ' Kolkata', ' Pune', ' Chennai', ' Kolkata', ' Mumbai', ' New Delhi', ' Hyderabad', ' Bangalore', ' Kochi', ' Jaipur', ' Ahmedabad', ' Kochi', ' Chennai', ' Jaipur', ' Chennai', ' Mumbai', ' Mumbai', ' Jaipur', ' Chennai', ' Ahmedabad', ' Raipur', ' Raipur', ' Hyderabad', ' Mumbai', ' Hyderabad', ' New Delhi', ' Hyderabad', ' Chennai', ' Ahmedabad', ' Raipur', ' Kochi', ' Raipur', ' Lucknow', ' Chennai', ' Hyderabad', ' Ahmedabad', ' Raipur', ' Bangalore', ' Jaipur', ' Bangalore', ' Raipur', ' Raipur', ' Mumbai', ' Ahmedabad', ' Ahmedabad', ' Ahmedabad', ' Mumbai', ' New Delhi', ' Kochi', ' Hyderabad', ' Ahmedabad', ' Kochi', ' Mumbai', ' Chennai', ' Bangalore', ' Chennai', ' Ahmedabad', ' Ahmedabad', ' Magrath Road', ' New Delhi', ' Ahmedabad', ' Hyderabad', ' Bangalore', ' Pune', ' Bangalore', ' Ahmedabad', ' Kochi', ' Hyderabad', ' Raipur', ' Bangalore', ' Bangalore', ' Kolkata', ' Jaipur', ' Raipur', ' Jaipur', ' Kolkata', ' Pune', ' Pune', ' Jaipur', ' Kochi', ' Ahmedabad', ' Kochi', ' Kochi', ' Chennai', ' Mumbai', ' New Delhi', ' Hyderabad', ' Lucknow', ' Mumbai', ' Ahmedabad', ' Chennai', ' Kochi', ' Lucknow', ' Mumbai', ' Jaipur', ' Jaipur', ' Bangalore', ' Mumbai', ' Raipur', ' Hyderabad', ' Jaipur', ' Hyderabad', ' New Delhi', ' Bangalore', ' Ahmedabad', ' Bangalore', ' Lucknow', ' Hyderabad', ' New Delhi', ' Hyderabad', ' Ahmedabad', ' Chennai', ' Ahmedabad', ' Ahmedabad', ' Kolkata', ' Bangalore', ' Chennai', ' Chennai', ' Jaipur', ' Bangalore', ' Pune', ' Bangalore', ' Jaipur', ' Hyderabad', ' Bangalore', ' Jaipur', ' Lucknow', ' Raipur', ' Jaipur', ' Mumbai', ' Kochi', ' Kochi', ' Raipur', ' Kolkata', ' New Delhi', ' Jaipur', ' Kolkata', ' Kolkata', ' Hyderabad', ' Kolkata', ' Chennai', ' Bangalore', ' Ahmedabad', ' Hyderabad', ' Mumbai', ' Chennai', ' Lucknow', ' Pune', ' Chennai', ' Mumbai', ' Raipur', ' New Delhi', ' Ahmedabad', ' Kochi', ' New Delhi', ' Chennai', ' Ahmedabad', ' Hyderabad', ' Hyderabad', ' Bangalore', ' Kochi', ' Kolkata', ' Chennai', ' Hyderabad', ' Chennai', ' Jaipur', ' Mumbai', ' Kochi', ' New Delhi', ' Bangalore', ' Mumbai', ' Hyderabad', ' Hyderabad', ' Ahmedabad', ' Kolkata', ' Mumbai', ' Pune', ' Raipur', ' Lucknow', ' New Delhi', ' Hyderabad', ' Kolkata', ' New Delhi', ' Lucknow', ' Bangalore', ' Hyderabad', ' Banaswadi', ' Ahmedabad', ' Ahmedabad', ' New Delhi', ' Chennai', ' Bangalore', ' Bangalore', ' Goa', ' Raipur', ' Bangalore', ' Kochi', ' Mumbai', ' Hyderabad', ' Chennai', ' Kolkata', ' Lucknow', ' Chennai', ' Jaipur', ' Jaipur', ' Bangalore', ' Bangalore', ' Pune', ' Jaipur', ' Hyderabad', ' Lucknow', ' Che ...
# <class 'list'>
# 123657
# prices
# [315.0, 230.0, 240.0, 144.07, 150.0, 239.0, 198.0, 250.0, 75.0, 79.0, 269.0, 14.29, 530.0, 120.0, 55.24, 109.52, 149.0, 339.0, 145.0, 125.0, 345.0, 294.0, 60.0, 220.0, 276.0, 142.0, 169.0, 280.0, 160.0, 130.0, 349.0, 260.0, 229.0, 114.28, 315.24, 155.0, 180.0, 195.0, 219.0, 179.0, 175.0, 161.9, 325.0, 148.0, 335.0, 249.0, 265.0, 290.0, 225.0, 50.0, 110.0, 200.0, 270.0, 450.0, 460.0, 275.0, 100.0, 30.0, 190.0, 25.0, 295.0, 310.0, 40.0, 135.0, 259.0, 170.0, 4.45, 99.0, 228.0, 140.0, 525.0, 1450.0, 261.0, 539.05, 121.5, 109.0, 350.0, 199.0, 57.14, 575.0, 80.0, 348.0, 47.61, 139.0, 189.0, 330.0, 115.0, 532.0, 328.0, 98.0, 90.0, 119.0, 403.0, 400.0, 244.0, 375.0, 210.0, 154.0, 75.24, 379.0, 359.0, 279.0, 260.24, 494.0, 499.0, 185.0, 103.81, 705.0, 92.0, 209.0, 36.14, 309.0, 20.0, 297.0, 810.0, 248.0, 329.0, 358.0, 162.0, 583.98, 261.91, 238.09, 101.69, 238.0, 500.0, 165.0, 95.0, 129.0, 455.0, 285.72, 185.71, 428.57, 36.34, 196.0, 67.8, 399.0, 255.0, 79.24, 300.0, 390.0, 223.0, 135.59, 288.0, 205.0, 555.0, 549.0, 15.0, 395.0, 385.0, 81.0, 215.0, 289.0, 610.0, 228.58, 509.25, 10.0, 112.5, 235.0, 140.95, 614.71, 299.0, 449.0, 178.0, 298.0, 402.54, 130.95, 598.0, 370.0, 380.0, 725.0, 45.0, 952.38, 39.0, 529.0, 748.57, 340.0, 175.71, 245.0, 363.0, 183.0, 336.0, 254.0, 1575.0, 410.0, 850.0, 365.0, 539.0, 13.0, 600.0, 320.0, 490.0, 650.0, 1209.0, 578.0, 65.0, 369.0, 440.0, 105.0, 128.0, 59.0, 456.0, 319.0, 278.0, 304.76, 94.29, 430.0, 70.0, 187.0, 470.0, 409.52, 268.0, 510.0, 168.0, 425.0, 220.95, 1000.0, 152.39, 419.0, 32.0, 68.0, 274.0, 462.0, 89.0, 194.0, 559.0, 895.0, 131.36, 188.0, 1179.0, 225.71, 415.0, 49.0, 408.34, 56.0, 1029.0, 229.5, 557.0, 515.0, 222.75, 384.76, 630.0, 489.0, 85.0, 18.75, 137.0, 710.0, 351.27, 179.4, 174.13, 280.8, 209.52, 78.0, 66.0, 381.0, 420.0, 819.0, 202.5, 389.0, 849.0, 258.1, 70.48, 128.58, 360.0, 69.0, 546.0, 394.0, 285.0, 518.0, 159.0, 612.0, 207.0, 349.53, 224.0, 278.1, 18.0, 1849.0, 253.0, 266.0, 1290.0, 127.12, 104.5, 212.33, 314.0, 219.04, 354.29, 695.0, 214.3, 83.0, 234.0, 429.0, 1599.0, 570.0, 22.0, 240.9, 699.0, 391.0, 688.57, 119.05, 1899.0, 114.29, 629.0, 11.0, 133.33, 125.71, 519.0, 422.86, 305.0, 199.05, 1050.0, 569.0, 378.0, 589.0, 219.05, 84.0, 228.57, 252.0, 640.0, 364.0, 28.6, 138.0, 368.0, 526.9, 520.0, 405.0, 306.67, 427.0, 2.0, 262.5, 33.0, 203.0, 399.3, 35.0, 343.0, 151.47, 599.0, 303.0, 271.44, 241.0, 501.0, 1129.0, 595.0, 158.0, 789.0, 101.0, 33.33, 355.0, 590.0, 233.05, 482.79, 479.0, 619.05, 273.0, 487.29, 258.0, 384.77, 649.0, 176.9, 14.4, 550.0, 309.99, 506.0, 398.0, 360.48, 459.0, 324.0, 513.29, 216.0, 159.5, 198.1, 338.0, 241.5, 468.0, 308.0, 422.29, 84.75, 337.0, 106.67, 120.48, 219.49, 267.62, 1999.0, 560.0, 75.89, 55.0, 217.0, 84.5, 367.86, 131.0, 114.0, 185.72, 237.5, 29.0, 94.0, 1600.0, 142.86, 153.0, 288.57, 218.0, 257.15, 447.0, 739.0, 366.0, 341.0, 53.57, 164.92, 44.0, 523.8, 439.0, 570.81, 22.86, 419.05, 338.98, 42.37, 95.24, 38.14, 619.0, 214.0, 224.76, 469.0, 284.76, 93.3, 299.04, 328.57, 103.53, 156.0, 190.48, 73.0, 869.0, 659.0, 34.0, 228.81, 466.1, 1072.0, 134.0, 76.27, 679.0, 88.0, 519.05, 53.0, 529.66, 435.0, 605.0, 19.0, 597.0, 322.03, 373.89, 495.0, 535.0, 254.24, 351.0, 110.17, 625.0, 550.84, 445.0, 118.0, 409.0, 97.0, 63.0, 480.0, 27.0, 151.0, 149.5, 157.14, 639.0, 76.0, 384.99, 52.0, 267.86, 310.48, 180.29, 223.21, 176.19, 357.0, 202.0, 378.1, 344.0, 996.0, 161.91, 342.0, 291.0, 496.0, 377.0, 313.56, 195.24, 141.0, 893.36, 12.0, 527.0, 177.0, 714.29, 284.96, 879.05, 1790.0, 167.4, 3300.0, 1219.0, 361.0, 399.05, 452.25, 132.0, 431.0, 118.64, 140.4, 24.0, 236.19, 90.48, 215.24, 399.27, 113.33, 208.0, 715.0, 221.0, 919.0, 1763.0, 263.46, 171.43, 175.24, 1570.0, 105.93, 25.42, 333.34, 152.38, 174.0, 139.05, 213.4, 929.0, 278.81, 2199.0, 135.71, 42.0, 5.0, 197.0, 77.97, 543.0, 312.0, 418.0, 164.0, 1200.0, 230.48, 113.0, 233.35, 138.1, 374.0, 66.67, 161.02, 160.95, 473.0, 204.77, 365.9, 96.0, 540.0, 47.0, 160.8, 229.52, 277.0, 231.0, 466.0, 1992.0, 47.25, 91.43 ...
# 4.35
# <class 'numpy.float64'>
# Test MSE: 0.03833676871352451
# Test Variance: 0.7370254249864255
